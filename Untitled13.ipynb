# %% [markdown]
# <a href="https://colab.research.google.com/github/DaltonWise/Homework/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)

# %%
data = read.csv('/content/ORES table formatted.csv')

# %%
data
# Out:
#    Characteristics      Both_Total None B_1st._4th_grade B_.5th._6th_grade
# 1  \t 18 years and over 253418     777  1364             2848
# 2  \t\t  18 to 24 years  28838      45    23               61
# 3  \t 25 years and over 224580     732  1341             2787
# 4  \t\t  25 to 29 years  22592      35    24               92
# 5  \t\t  30 to 34 years  22691      34    52              162
# 6  \t\t  35 to 39 years  21607      48    99              277
# 7  \t\t  40 to 44 years  20397      34   113              308
# 8  \t\t  45 to 49 years  19406      71   103              302
# 9  \t\t  50 to 54 years  20273      80   125              244
# 10 \t\t  55 to 59 years  20682      56   168              280
# 11 \t\t  60 to 64 years  21094      96   160              291
# 12 \t\t  65 to 69 years  18162      67   121              228
# 13 \t\t  70 to 74 years  14878      82   118              189
# 14 \t 75 years and over  22796     130   259              412
# ...

# %%
#data2 <- data%>%
  #select(Both_total)

# %%
View(data)

# %%
data$Male_Total = NULL
data$Female_Total = NULL

data$'18 years and over' = NULL
data$'25 years and over' = NULL

# %%
data %>%
  filter(Characteristics == "18 years and over")

# %%
nrow(data)
# Out:
# [1] 14

# %%
library(tidyverse)

#https://www.youtube.com/watch?v=tp_BG5wDeVU


data %>% ggplot(aes(x = Male_Total)) +
  geom_histogram(binwidth = 1000)
theme_bw()+
  labs(x = "Male total population",
       y = 'frequency',
       title = "total population"
  )
# Out:
# List of 99
#  $ line                      :List of 6
#   ..$ colour       : chr "black"
#   ..$ linewidth    : num 0.5
#   ..$ linetype     : num 1
#   ..$ lineend      : chr "butt"
#   ..$ arrow        : logi FALSE
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_line" "element"
#  $ rect                      :List of 5
#   ..$ fill         : chr "white"
#   ..$ colour       : chr "black"
#   ..$ linewidth    : num 0.5
#   ..$ linetype     : num 1
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_rect" "element"
#  $ text                      :List of 11
#   ..$ family       : chr ""
#   ..$ face         : chr "plain"
#   ..$ colour       : chr "black"
#   ..$ size         : num 11
#   ..$ hjust        : num 0.5
#   ..$ vjust        : num 0.5
#   ..$ angle        : num 0
#   ..$ lineheight   : num 0.9
#   ..$ margin       : 'margin' num [1:4] 0points 0points 0points 0points
#   .. ..- attr(*, "unit")= int 8
# ...

# %%
library(tidyverse)

#https://www.youtube.com/watch?v=tp_BG5wDeVU


data %>% ggplot(aes(x = Female_Total)) +
  geom_histogram(binwidth = 1000)
theme_bw()+
  labs(x = "Female total population",
       y = 'frequency',
       title = "total population"
  )
# Out:
# List of 99
#  $ line                      :List of 6
#   ..$ colour       : chr "black"
#   ..$ linewidth    : num 0.5
#   ..$ linetype     : num 1
#   ..$ lineend      : chr "butt"
#   ..$ arrow        : logi FALSE
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_line" "element"
#  $ rect                      :List of 5
#   ..$ fill         : chr "white"
#   ..$ colour       : chr "black"
#   ..$ linewidth    : num 0.5
#   ..$ linetype     : num 1
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_rect" "element"
#  $ text                      :List of 11
#   ..$ family       : chr ""
#   ..$ face         : chr "plain"
#   ..$ colour       : chr "black"
#   ..$ size         : num 11
#   ..$ hjust        : num 0.5
#   ..$ vjust        : num 0.5
#   ..$ angle        : num 0
#   ..$ lineheight   : num 0.9
#   ..$ margin       : 'margin' num [1:4] 0points 0points 0points 0points
#   .. ..- attr(*, "unit")= int 8
# ...

# %%
data %>%
  (aes(x = 'Characteristics',
       y = 'Female_Bachelor_degree' )) +
  geom_point()
theme_bw()+
  labs(x = "Age Brackets",
       y = 'frequency',
       title = "total population per age group"
  )
# Out:
# List of 99
#  $ line                      :List of 6
#   ..$ colour       : chr "black"
#   ..$ linewidth    : num 0.5
#   ..$ linetype     : num 1
#   ..$ lineend      : chr "butt"
#   ..$ arrow        : logi FALSE
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_line" "element"
#  $ rect                      :List of 5
#   ..$ fill         : chr "white"
#   ..$ colour       : chr "black"
#   ..$ linewidth    : num 0.5
#   ..$ linetype     : num 1
#   ..$ inherit.blank: logi TRUE
#   ..- attr(*, "class")= chr [1:2] "element_rect" "element"
#  $ text                      :List of 11
#   ..$ family       : chr ""
#   ..$ face         : chr "plain"
#   ..$ colour       : chr "black"
#   ..$ size         : num 11
#   ..$ hjust        : num 0.5
#   ..$ vjust        : num 0.5
#   ..$ angle        : num 0
#   ..$ lineheight   : num 0.9
#   ..$ margin       : 'margin' num [1:4] 0points 0points 0points 0points
#   .. ..- attr(*, "unit")= int 8
# ...

# %%
data_new = data[0:12]

# %%
#data_new = data[!data$Characteristics %in% c('18 years and over','25 years and over'),]
#data_new = data[data$Characteristics %in% c("18 years and over", "25 years and od
data <- data[-1, ]


data

# %%
data

# %%
data <- data[-3, ]
data

# %%
new_data = data[data$x1 != 1]

# %%
names(data)

# %%
head(new_data)

# %%
data %>%
  ggplot(aes(Both_total))+
  geom_bar(fill = '#97B3C6')
# Out:
# ERROR while rich displaying an object: Error in `geom_bar()`:
# ! Problem while computing aesthetics.
# ℹ Error occurred in the 1st layer.
# Caused by error:
# ! object 'Both_total' not found
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
# ...
