# %% [markdown]
# <a href="https://colab.research.google.com/github/DaltonWise/Homework/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

# %%
burden = pd.read_csv('/content/burden-disease-from-each-mental-illness.csv')

#https://ourworldindata.org/mental-health

#DALY explanation: https://www.who.int/data/gho/indicator-metadata-registry/imr-details/158#:~:text=Definition%3A-,One%20DALY%20represents%20the%20loss%20of%20the%20equivalent%20of%20one,health%20condition%20in%20a%20population.

# %%
mental_health = pd.read_csv('/content/mental_health_depression_disorder.csv')

#https://www.kaggle.com/datasets/thedevastator/uncover-global-trends-in-mental-health-disorder
# Out:
# <ipython-input-4-b0fb47130264>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   mental_health = pd.read_csv('/content/mental_health_depression_disorder.csv')

# %%
burden.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DALYs from depressive disorders per 100,000 people in, both sexes aged age-standardized  \
# 0                                          895.22565
# 1                                          893.88434
# 2                                          892.34973
# 3                                          891.51587
# 4                                          891.39160
#
#    DALYs from schizophrenia per 100,000 people in, both sexes aged age-standardized  \
# 0                                          138.24825
# 1                                          137.76122
# 2                                          137.08030
# 3                                          136.48602
# 4                                          136.18323
#
# ...

# %%
mental_health.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
burden.merge(mental_health, on = 'Entity')
#This was my first merge. I realized I could merge on the first three columns in both dataframes.
#To do that I had to make sure they all had the same data types.

# %%
burden['Year'] = burden['Year'].values.astype(str)
mental_health['Year'] = mental_health['Year'].values.astype(str)


#In this cell I am converting each of the year columns to a string. The reason I do this is because when using 'pd.merge' an error was raised stating I was trying to merge a string and a int64.
#I assume that in one of the two data frames the year was a string and the other it was an integer.

#https://sparkbyexamples.com/pandas/pandas-convert-columns-to-string-type/

# %%
health_merged = pd.merge(burden, mental_health, on = ['Entity', 'Code', 'Year'])

# %%
health_merged
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1990
# 1      Afghanistan  AFG  1990
# 2      Afghanistan  AFG  1990
# 3      Afghanistan  AFG  1990
# 4      Afghanistan  AFG  1991
# ...            ...  ...   ...
# 23255     Zimbabwe  ZWE  2017
# 23256     Zimbabwe  ZWE  2018
# 23257     Zimbabwe  ZWE  2018
# 23258     Zimbabwe  ZWE  2019
# 23259     Zimbabwe  ZWE  2019
#
#        DALYs from depressive disorders per 100,000 people in, both sexes aged age-standardized  \
# 0                                              895.22565
# 1                                              895.22565
# 2                                              895.22565
# 3                                              895.22565
# 4                                              893.88434
# ...                                                  ...
# 23255                                          547.62270
# 23256                                          546.57184
# ...

# %%
health_merged['Year'].unique()
#Trying to see the range of years in this data set. I would like to try to find world population data from that year range.
# Out:
# array(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019'], dtype=object)

# %%
world_population = pd.read_excel('/content/world_population_excel.xls', skiprows = [0, 1, 2, 3])

#https://data.worldbank.org/indicator/SP.POP.TOTL?most_recent_year_desc=false

#skipping rows: https://stackoverflow.com/questions/20637439/skip-rows-during-csv-import-pandas

# %%
world_population.head()
# Out:
#                          Aruba  ABW  Population, total  SP.POP.TOTL  \
# 0  Africa Eastern and Southern  AFE  Population, total  SP.POP.TOTL
# 1                  Afghanistan  AFG  Population, total  SP.POP.TOTL
# 2   Africa Western and Central  AFW  Population, total  SP.POP.TOTL
# 3                       Angola  AGO  Population, total  SP.POP.TOTL
# 4                      Albania  ALB  Population, total  SP.POP.TOTL
#
#          54608        55811        56682        57475        58178  \
# 0  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 1    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 2   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 3    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
# 4    1608800.0    1659800.0    1711319.0    1762621.0    1814135.0
#
#          58782  ...       102880       103594       104257       104874  \
# 0  149742351.0  ...  567892149.0  583651101.0  600008424.0  616377605.0
# ...

# %%
world_population2 = pd.read_excel('/content/world_population_excel_2.xls')

#Okay so this is the same data set as the last one. I was having trouble importing the original excel format because of the added cells for explanation in the original data set.
#I am going to email Professor Boal asking with this so that I am doing the project fully.

# %%
world_population2
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
population = world_population2.drop(['Indicator Name', 'Indicator Code'], axis = 1)

#Dropping those two columns so that I can hopefully unpivot this data.

# %%
population.head()
# Out:
#                   Country Name Country Code         1960         1961  \
# 0                        Aruba          ABW      54608.0      55811.0
# 1  Africa Eastern and Southern          AFE  130692579.0  134169237.0
# 2                  Afghanistan          AFG    8622466.0    8790140.0
# 3   Africa Western and Central          AFW   97256290.0   99314028.0
# 4                       Angola          AGO    5357195.0    5441333.0
#
#           1962         1963         1964         1965         1966  \
# 0      56682.0      57475.0      58178.0      58782.0      59291.0
# 1  137835590.0  141630546.0  145605995.0  149742351.0  153955516.0
# 2    8969047.0    9157465.0    9355514.0    9565147.0    9783147.0
# 3  101445032.0  103667517.0  105959979.0  108336203.0  110798486.0
# 4    5521400.0    5599827.0    5673199.0    5736582.0    5787044.0
#
#           1967  ...         2013         2014         2015         2016  \
# ...

# %%
population = population.set_index(["Country Name", "Country Code"])
population.head()

#Because I am trying to pivot the data, I am converting the country name and country code to the index.
#This will allow me to make the year one single column.
# Out:
#                                                  1960         1961  \
# Country Name                Country Code
# Aruba                       ABW               54608.0      55811.0
# Africa Eastern and Southern AFE           130692579.0  134169237.0
# Afghanistan                 AFG             8622466.0    8790140.0
# Africa Western and Central  AFW            97256290.0   99314028.0
# Angola                      AGO             5357195.0    5441333.0
#
#                                                  1962         1963  \
# Country Name                Country Code
# Aruba                       ABW               56682.0      57475.0
# Africa Eastern and Southern AFE           137835590.0  141630546.0
# Afghanistan                 AFG             8969047.0    9157465.0
# Africa Western and Central  AFW           101445032.0  103667517.0
# Angola                      AGO             5521400.0    5599827.0
#
#                                                  1964         1965  \
# ...

# %%
population2 = population.stack().reset_index()

# %%
population2
# Out:
#       Country Name Country Code level_2           0
# 0            Aruba          ABW    1960     54608.0
# 1            Aruba          ABW    1961     55811.0
# 2            Aruba          ABW    1962     56682.0
# 3            Aruba          ABW    1963     57475.0
# 4            Aruba          ABW    1964     58178.0
# ...            ...          ...     ...         ...
# 16660     Zimbabwe          ZWE    2018  15052184.0
# 16661     Zimbabwe          ZWE    2019  15354608.0
# 16662     Zimbabwe          ZWE    2020  15669666.0
# 16663     Zimbabwe          ZWE    2021  15993524.0
# 16664     Zimbabwe          ZWE    2022  16320537.0
#
# [16665 rows x 4 columns]

# %%
population2.columns = ['Entity', 'Code', 'Year', 'Total_Population']
#Changing the names to match the previous two data sets.

# %%
population2.head()
# Out:
#   Entity Code  Year  Total_Population
# 0  Aruba  ABW  1960           54608.0
# 1  Aruba  ABW  1961           55811.0
# 2  Aruba  ABW  1962           56682.0
# 3  Aruba  ABW  1963           57475.0
# 4  Aruba  ABW  1964           58178.0

# %%
second_merge = pd.merge(health_merged, population2, how = 'left', on = ['Entity', 'Code', 'Year'])

#I used a left merge so that I would only be pulling records from 'population2' that matched records from 'health_merged'.
#I can see by comparing that 'second_merge' and 'health_merged' both have 23,260 rows. I was going to try to right an expression to show that.
#The only thing I could think to do was try to use the shape function to prove they were both the same but they actually have a different number of columns so I cant.
#Either way my point stands that I only returned the records matching from health_merged.

# %%
second_merge
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1990
# 1      Afghanistan  AFG  1990
# 2      Afghanistan  AFG  1990
# 3      Afghanistan  AFG  1990
# 4      Afghanistan  AFG  1991
# ...            ...  ...   ...
# 23255     Zimbabwe  ZWE  2017
# 23256     Zimbabwe  ZWE  2018
# 23257     Zimbabwe  ZWE  2018
# 23258     Zimbabwe  ZWE  2019
# 23259     Zimbabwe  ZWE  2019
#
#        DALYs from depressive disorders per 100,000 people in, both sexes aged age-standardized  \
# 0                                              895.22565
# 1                                              895.22565
# 2                                              895.22565
# 3                                              895.22565
# 4                                              893.88434
# ...                                                  ...
# 23255                                          547.62270
# 23256                                          546.57184
# ...

# %%
#second_merge.fillna(0)
#I am not sure if I should fill all of these nan values or not yet. It could affect aggregation I think.

# %% [markdown]
# **Testing Datasets:**
#
# This section is for uploading data sets to see if they are going to be something we can work through. It is easier for me to get a handle of what I am looking at once I upload it to colab so these are the ones that were not used.

# %%
facility = pd.read_excel('/content/health_facility_locations.xlsx')
facility.head()
facility.columns
facility['FACNAME'].value_counts

# %%
#ssi2021 = pd.read_csv('/content/Surgical-Site-Infections-California-Hospitals-2021.csv', encoding='UTF-8')
#https://catalog.data.gov/dataset/surgical-site-infections-ssis-for-operative-procedures-in-california-hospitals-62337

#ssi2022 = pd.read_csv('https://catalog.data.gov/dataset/surgical-site-infections-ssis-for-operative-procedures-in-california-hospitals-62337',)
#https://catalog.data.gov/dataset/surgical-site-infections-ssis-for-operative-procedures-in-california-hospitals-62337

# %%
with open('/content/Surgical-Site-Infections-California-Hospitals-2021.csv') as f:
    print(f)


#When trying to upload these files into colab I am getting an error stating it is unable to
# Out:
# <_io.TextIOWrapper name='/content/Surgical-Site-Infections-California-Hospitals-2021.csv' mode='r' encoding='UTF-8'>

# %%
ocd_patient = pd.read_csv('/content/ocd_patient_dataset.csv')

# %%
vax = pd.read_csv('/content/Special_Vaccine_Locations.csv')

#https://catalog.data.gov/dataset/special-vaccine-locations

vax.head()

# %%
#mi = pd.read_csv('/content/myocardial+infarction+complications.zip')
#mi.head()

social = pd.read_csv('/content/archive.zip')
social.head()

# %%
ocd_patient.head()

# %%
#ocd_json = pd.read_json('https://www.ebi.ac.uk/biostudies/files/S-EPMC2943932/S-EPMC2943932.json')

#ocd_json = json.load(open('/content/OCD.json'))
#ocd_json = pd.DataFrame(ocd_json)

#This is a JSON data set I was trying to juse that kept not running properly. I may use it again but I think because of the way it is formatted it will be tough for me to use.

# %%
student = pd.read_csv('/content/archive (1).zip')
student.head()

# %% [markdown]
# **Websites:**
#
# Creating a folder for github:
#
# *   https://berrasari.medium.com/creating-folders-on-github-a-step-by-step-guide-fb0b44b98561#:~:text=Steps%20to%20Create%20Folders%20on%20GitHub&text=Choose%20the%20repository%20where%20you,the%20slash%20at%20the%20end.
#
# Kaggle OCD dataset:
#
# *   https://www.kaggle.com/datasets/ohinhaque/ocd-patient-dataset-demographics-and-clinical-data
#
# Chat gpt webpage week 13 assignment:
#
# *   https://chat.openai.com/share/50db56ab-ffcb-405d-869a-9f4e6f04b76c
#
# Predictors and moderators of treatment outcome in the Pediatric Obsessive Compulsive Treatment Study (POTS I) AND its accompanying JSON file. This is the one that would not work.
#
# *   https://www.ebi.ac.uk/biostudies/europepmc/studies/S-EPMC2943932
# *   https://www.ebi.ac.uk/biostudies/files/S-EPMC2943932/S-EPMC2943932.json
#
# Social Media and Mental Health: archive data frame
#
# *   https://www.kaggle.com/datasets/souvikahmed071/social-media-and-mental-health
#
# Student Mental Health: archive(1).zip:
#
# *   https://www.kaggle.com/datasets/shariful07/student-mental-health
