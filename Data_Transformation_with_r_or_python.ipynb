# %% [markdown]
# <a href="https://colab.research.google.com/github/DaltonWise/Homework/blob/main/Data_Transformation_with_r_or_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/ORES table formatted.csv')

#This is assignining the info as a data frame so it can be parced properly.
df = pd.DataFrame(data)

#showing myself how the data looks here.
df.head()
# Out:
#         Characteristics  Both_Total   None  B_1st _4th_grade  \
# 0  \t 18 years and over      253418  777.0            1364.0
# 1  \t\t  18 to 24 years       28838   45.0              23.0
# 2  \t 25 years and over      224580  732.0            1341.0
# 3  \t\t  25 to 29 years       22592   35.0              24.0
# 4  \t\t  30 to 34 years       22691   34.0              52.0
#
#    B_ 5th _6th_grade  B _7th _8th_grade  B_9th_grade  B_10th_grade  \
# 0             2848.0             3252.0       3063.0        3489.0
# 1               61.0              177.0        236.0         491.0
# 2             2787.0             3076.0       2827.0        2998.0
# 3               92.0              127.0        187.0         176.0
# 4              162.0              193.0        265.0         231.0
#
#    B_11th_grade2  B_High_school_graduate  ...  F_10th_grade  F_11th_grade2  \
# 0         9541.0                 71742.0  ...        1624.0         4556.0
# 1         3249.0                  9194.0  ...         228.0         1489.0
# 2         6293.0                 62547.0  ...        1396.0         3067.0
# 3          640.0                  6305.0  ...          67.0          276.0
# 4          634.0                  5627.0  ...         104.0          257.0
#
#    F_High_school_graduate  F_Some_college_no_degree  \
# 0                 34753.0                   22316.0
# 1                  4061.0                    5160.0
# 2                 30693.0                   17156.0
# 3                  2585.0                    1849.0
# 4                  2411.0                    1626.0
#
#    F_Associate'_degree_occupational  F_Associate_degree_academic  \
# 0                            5560.0                       8619.0
# 1                             314.0                        675.0
# 2                            5246.0                       7945.0
# 3                             481.0                        788.0
# 4                             491.0                        741.0
#
#    F_Bachelor_degree  F_Master_degree  F_Professional_degree  \
# 0            29971.0          13942.0                 1477.0
# 1             1938.0            149.0                    2.0
# 2            28033.0          13793.0                 1475.0
# 3             3561.0           1078.0                  101.0
# 4             3423.0           1557.0                  171.0
#
#    F_Doctoral_degree
# 0             2144.0
# 1                3.0
# 2             2141.0
# 3              121.0
# 4              249.0
#
# [5 rows x 49 columns]

# %% [markdown]
# **Dropping Columns**

# %%
#I dropped each of these columns because they lead to outliers in the data and take away from some of the correlation in graphs.
#I do not think it is valuable to have the total of both, men, and women. These values are much larger and do not help show any trend.
df.drop(['Both_Total', 'Male_Total', 'Female_Total'], axis=1, inplace=True)
df.head()
# Out:
#         Characteristics   None  B_1st _4th_grade  B_ 5th _6th_grade  \
# 0  \t 18 years and over  777.0            1364.0             2848.0
# 1  \t\t  18 to 24 years   45.0              23.0               61.0
# 2  \t 25 years and over  732.0            1341.0             2787.0
# 3  \t\t  25 to 29 years   35.0              24.0               92.0
# 4  \t\t  30 to 34 years   34.0              52.0              162.0
#
#    B _7th _8th_grade  B_9th_grade  B_10th_grade  B_11th_grade2  \
# 0             3252.0       3063.0        3489.0         9541.0
# 1              177.0        236.0         491.0         3249.0
# 2             3076.0       2827.0        2998.0         6293.0
# 3              127.0        187.0         176.0          640.0
# 4              193.0        265.0         231.0          634.0
#
#    B_High_school_graduate  B_Some_college_no_degree  ...  F_10th_grade  \
# 0                 71742.0                   43324.0  ...        1624.0
# 1                  9194.0                    9869.0  ...         228.0
# 2                 62547.0                   33455.0  ...        1396.0
# 3                  6305.0                    3891.0  ...          67.0
# 4                  5627.0                    3438.0  ...         104.0
#
#    F_11th_grade2  F_High_school_graduate  F_Some_college_no_degree  \
# 0         4556.0                 34753.0                   22316.0
# 1         1489.0                  4061.0                    5160.0
# 2         3067.0                 30693.0                   17156.0
# 3          276.0                  2585.0                    1849.0
# 4          257.0                  2411.0                    1626.0
#
#    F_Associate'_degree_occupational  F_Associate_degree_academic  \
# 0                            5560.0                       8619.0
# 1                             314.0                        675.0
# 2                            5246.0                       7945.0
# 3                             481.0                        788.0
# 4                             491.0                        741.0
#
#    F_Bachelor_degree  F_Master_degree  F_Professional_degree  \
# 0            29971.0          13942.0                 1477.0
# 1             1938.0            149.0                    2.0
# 2            28033.0          13793.0                 1475.0
# 3             3561.0           1078.0                  101.0
# 4             3423.0           1557.0                  171.0
#
#    F_Doctoral_degree
# 0             2144.0
# 1                3.0
# 2             2141.0
# 3              121.0
# 4              249.0
#
# [5 rows x 46 columns]

# %%
#These two commands remove the rows indicated.
#Below removes row 0.
df.drop(0, axis=0, inplace = True)
#Below removes row 2.
df.drop(2, axis=0, inplace = True)
df.head()
# Out:
#         Characteristics  None  B_1st _4th_grade  B_ 5th _6th_grade  \
# 1  \t\t  18 to 24 years  45.0              23.0               61.0
# 3  \t\t  25 to 29 years  35.0              24.0               92.0
# 4  \t\t  30 to 34 years  34.0              52.0              162.0
# 5  \t\t  35 to 39 years  48.0              99.0              277.0
# 6  \t\t  40 to 44 years  34.0             113.0              308.0
#
#    B _7th _8th_grade  B_9th_grade  B_10th_grade  B_11th_grade2  \
# 1              177.0        236.0         491.0         3249.0
# 3              127.0        187.0         176.0          640.0
# 4              193.0        265.0         231.0          634.0
# 5              280.0        311.0         292.0          571.0
# 6              299.0        315.0         270.0          566.0
#
#    B_High_school_graduate  B_Some_college_no_degree  ...  F_10th_grade  \
# 1                  9194.0                    9869.0  ...         228.0
# 3                  6305.0                    3891.0  ...          67.0
# 4                  5627.0                    3438.0  ...         104.0
# 5                  5002.0                    3083.0  ...         140.0
# 6                  5039.0                    2744.0  ...         141.0
#
#    F_11th_grade2  F_High_school_graduate  F_Some_college_no_degree  \
# 1         1489.0                  4061.0                    5160.0
# 3          276.0                  2585.0                    1849.0
# 4          257.0                  2411.0                    1626.0
# 5          259.0                  2127.0                    1506.0
# 6          256.0                  2166.0                    1394.0
#
#    F_Associate'_degree_occupational  F_Associate_degree_academic  \
# 1                             314.0                        675.0
# 3                             481.0                        788.0
# 4                             491.0                        741.0
# 5                             417.0                        790.0
# 6                             463.0                        719.0
#
#    F_Bachelor_degree  F_Master_degree  F_Professional_degree  \
# 1             1938.0            149.0                    2.0
# 3             3561.0           1078.0                  101.0
# 4             3423.0           1557.0                  171.0
# 5             3081.0           1656.0                  179.0
# 6             2651.0           1592.0                  210.0
#
#    F_Doctoral_degree
# 1                3.0
# 3              121.0
# 4              249.0
# 5              256.0
# 6              228.0
#
# [5 rows x 46 columns]

# %% [markdown]
# **Transforming data types**

# %%
#This is showing the data types of each column in the data set.

#I am going to change some of them to integers to show that I know how.
df.dtypes
# Out:
# Characteristics                      object
# None                                float64
# B_1st _4th_grade                    float64
# B_ 5th _6th_grade                   float64
# B _7th _8th_grade                   float64
# B_9th_grade                         float64
# B_10th_grade                        float64
# B_11th_grade2                       float64
# B_High_school_graduate              float64
# B_Some_college_no_degree            float64
# B_Associate_degree_occupational     float64
# B_Associate_degree_academic         float64
# B_Bachelor_degree                   float64
# B_Master_degree                     float64
# B_Professional_degree               float64
# B_Doctoral_degree                   float64
# None.1                              float64
# M_1st _ 4th_grade                   float64
# M_5th _ 6th_grade                   float64
# M_7th _8th_grade                    float64
# M_9th_grade                         float64
# M_10th_grade                        float64
# M_11th_grade2                       float64
# M_High_school_graduate              float64
# M_Some_college_no_degree            float64
# M_Associate_degree_occupational     float64
# M_Associate_degree_academic         float64
# M_Bachelor_degree                   float64
# M_Master_degree                     float64
# M_Professional_degree               float64
# M_Doctoral_degree                   float64
# None.2                              float64
# F_1st _4th_grade                    float64
# F_5th_6th_grade                     float64
# F_7th _8th_grade                    float64
# F_9th_grade                         float64
# F_10th_grade                        float64
# F_11th_grade2                       float64
# F_High_school_graduate              float64
# F_Some_college_no_degree            float64
# F_Associate'_degree_occupational    float64
# F_Associate_degree_academic         float64
# F_Bachelor_degree                   float64
# F_Master_degree                     float64
# F_Professional_degree               float64
# F_Doctoral_degree                   float64
# dtype: object

# %%
#I chose to convert the columns representing masters degrees to convert from float to integer.


#It is actually better to use integers over floats when you can because it improve computational speed.
#Integers are stored as fixed values while floats can be stored in a number of ways that all require computation before being identified.
#https://discuss.codecademy.com/t/if-most-numbers-can-be-represented-as-a-float-value-why-would-we-need-to-use-integers/347282#:~:text=The%20advantage%20of%20int%20over,just%20in%20assessing%20the%20value.
#We also literally do not need them to be floats because none of them have decimal values.


#Both
df['B_Bachelor_degree'] = df['B_Bachelor_degree'].astype(int)
df['B_Master_degree'] = df['B_Master_degree'].astype(int)
df['B_Professional_degree'] = df['B_Professional_degree'].astype(int)
df['B_Doctoral_degree'] = df['B_Doctoral_degree'].astype(int)
#Male
df['M_Bachelor_degree'] = df['M_Bachelor_degree'].astype(int)
df['M_Master_degree'] = df['M_Master_degree'].astype(int)
df['M_Professional_degree'] = df['M_Professional_degree'].astype(int)
df['M_Doctoral_degree'] = df['M_Doctoral_degree'].astype(int)
#Female
df['F_Bachelor_degree'] = df['F_Bachelor_degree'].astype(int)
df['F_Master_degree'] = df['F_Master_degree'].astype(int)
df['F_Professional_degree'] = df['F_Professional_degree'].astype(int)
df['F_Doctoral_degree'] = df['F_Doctoral_degree'].astype(int)

# %%
#I used the print function to show the type had changed.
#I did not want include each one as it seemed unnecessary.
#This is me showing that the data types have been correctly altered.
print(df['B_Master_degree'].dtypes)
print(df['M_Master_degree'].dtypes)
print(df['F_Master_degree'].dtypes)
# Out:
# int64
# int64
# int64

# %% [markdown]
# **Renaming Columns**

# %%
#This is me renaming the degrees to something  that looks better.
df.rename(columns = {'B_Bachelor_degree' : 'B_Bachelor', 'B_Master_degree' : 'B_Master', 'B_Professional_degree' : 'B_Professional', 'B_Doctoral_degree' : 'B_Doctoral',
                     'M_Bachelor_degree' : 'M_Bachelor', 'M_Master_degree' : 'M_Master', 'M_Professional_degree' : 'M_Professional', 'M_Doctoral_degree' : 'M_Doctoral',
                     'F_Bachelor_degree' : 'F_Bachelor', 'F_Master_degree' : 'F_Master', 'F_Professional_degree' : 'F_Professional', 'F_Doctoral_degree' : 'F_Doctoral',
                    } , inplace = True)
df.columns
# Out:
# Index(['Characteristics', 'None', 'B_1st _4th_grade', 'B_ 5th _6th_grade',
#        'B _7th _8th_grade', 'B_9th_grade', 'B_10th_grade', 'B_11th_grade2',
#        'B_High_school_graduate', 'B_Some_college_no_degree',
#        'B_Associate_degree_occupational', 'B_Associate_degree_academic',
#        'B_Bachelor', 'B_Master', 'B_Professional', 'B_Doctoral', 'None.1',
#        'M_1st _ 4th_grade', 'M_5th _ 6th_grade', 'M_7th _8th_grade',
#        'M_9th_grade', 'M_10th_grade', 'M_11th_grade2',
#        'M_High_school_graduate', 'M_Some_college_no_degree',
#        'M_Associate_degree_occupational', 'M_Associate_degree_academic',
#        'M_Bachelor', 'M_Master', 'M_Professional', 'M_Doctoral', 'None.2',
#        'F_1st _4th_grade', 'F_5th_6th_grade', 'F_7th _8th_grade',
#        'F_9th_grade', 'F_10th_grade', 'F_11th_grade2',
#        'F_High_school_graduate', 'F_Some_college_no_degree',
#        'F_Associate'_degree_occupational', 'F_Associate_degree_academic',
#        'F_Bachelor', 'F_Master', 'F_Professional', 'F_Doctoral'],
#       dtype='object')

# %%
#This is me renaming the masters degrees to something  that looks better.
df.rename(columns = {'B_Master_degree' : 'B_Master', 'M_Master_degree' : 'M_Master', 'F_Master_degree' : 'F_Master'}, inplace = True)
df.columns
# Out:
# Index(['Characteristics', 'None', 'B_1st _4th_grade', 'B_ 5th _6th_grade',
#        'B _7th _8th_grade', 'B_9th_grade', 'B_10th_grade', 'B_11th_grade2',
#        'B_High_school_graduate', 'B_Some_college_no_degree',
#        'B_Associate_degree_occupational', 'B_Associate_degree_academic',
#        'B_Bachelor', 'B_Master', 'B_Professional', 'B_Doctoral', 'None.1',
#        'M_1st _ 4th_grade', 'M_5th _ 6th_grade', 'M_7th _8th_grade',
#        'M_9th_grade', 'M_10th_grade', 'M_11th_grade2',
#        'M_High_school_graduate', 'M_Some_college_no_degree',
#        'M_Associate_degree_occupational', 'M_Associate_degree_academic',
#        'M_Bachelor', 'M_Master', 'M_Professional', 'M_Doctoral', 'None.2',
#        'F_1st _4th_grade', 'F_5th_6th_grade', 'F_7th _8th_grade',
#        'F_9th_grade', 'F_10th_grade', 'F_11th_grade2',
#        'F_High_school_graduate', 'F_Some_college_no_degree',
#        'F_Associate'_degree_occupational', 'F_Associate_degree_academic',
#        'F_Bachelor', 'F_Master', 'F_Professional', 'F_Doctoral'],
#       dtype='object')

# %% [markdown]
# **Create calculated data field**

# %%
#This will show all the males in each age frame with a bachelors degree or higher. Those with a college education.
Male_Degree = ['M_Bachelor', 'M_Master', 'M_Professional', 'M_Doctoral']
df['Male_Degree'] = df[Male_Degree].sum(axis=1, skipna=False)
df['Male_Degree']
# Out:
# 1     1613
# 3     3945
# 4     4290
# 5     4212
# 6     3878
# 7     3571
# 8     3791
# 9     3257
# 10    3273
# 11    3053
# 12    2642
# 13    3682
# Name: Male_Degree, dtype: int64

# %%
#All women of a certain age bracket with atleast a bachelor degree.
Female_Degree = ['F_Bachelor', 'F_Master', 'F_Professional', 'F_Doctoral']
df['Female_Degree'] = df[Female_Degree].sum(axis=1, skipna=False)
df['Female_Degree']
# Out:
# 1     2092
# 3     4861
# 4     5400
# 5     5172
# 6     4681
# 7     4424
# 8     4317
# 9     3891
# 10    3741
# 11    3135
# 12    2537
# 13    3285
# Name: Female_Degree, dtype: int64

# %% [markdown]
# **Drop Duplicates**

# %%
#I am pretty sure I have no duplicate values.
#If I did they are gone.
df.drop_duplicates()
# Out:
#          Characteristics   None  B_1st _4th_grade  B_ 5th _6th_grade  \
# 1   \t\t  18 to 24 years   45.0              23.0               61.0
# 3   \t\t  25 to 29 years   35.0              24.0               92.0
# 4   \t\t  30 to 34 years   34.0              52.0              162.0
# 5   \t\t  35 to 39 years   48.0              99.0              277.0
# 6   \t\t  40 to 44 years   34.0             113.0              308.0
# 7   \t\t  45 to 49 years   71.0             103.0              302.0
# 8   \t\t  50 to 54 years   80.0             125.0              244.0
# 9   \t\t  55 to 59 years   56.0             168.0              280.0
# 10  \t\t  60 to 64 years   96.0             160.0              291.0
# 11  \t\t  65 to 69 years   67.0             121.0              228.0
# 12  \t\t  70 to 74 years   82.0             118.0              189.0
# 13  \t 75 years and over  130.0             259.0              412.0
#
#     B _7th _8th_grade  B_9th_grade  B_10th_grade  B_11th_grade2  \
# 1               177.0        236.0         491.0         3249.0
# 3               127.0        187.0         176.0          640.0
# 4               193.0        265.0         231.0          634.0
# 5               280.0        311.0         292.0          571.0
# 6               299.0        315.0         270.0          566.0
# 7               265.0        236.0         254.0          460.0
# 8               293.0        289.0         223.0          491.0
# 9               269.0        260.0         329.0          601.0
# 10              263.0        242.0         275.0          637.0
# 11              229.0        170.0         229.0          495.0
# 12              250.0        198.0         254.0          375.0
# 13              610.0        355.0         465.0          823.0
#
#     B_High_school_graduate  B_Some_college_no_degree  ...  \
# 1                   9194.0                    9869.0  ...
# 3                   6305.0                    3891.0  ...
# 4                   5627.0                    3438.0  ...
# 5                   5002.0                    3083.0  ...
# 6                   5039.0                    2744.0  ...
# 7                   4910.0                    2618.0  ...
# 8                   5509.0                    2772.0  ...
# 9                   6147.0                    2978.0  ...
# 10                  6581.0                    3197.0  ...
# 11                  5415.0                    3017.0  ...
# 12                  4205.0                    2464.0  ...
# 13                  7807.0                    3254.0  ...
#
#     F_High_school_graduate  F_Some_college_no_degree  \
# 1                   4061.0                    5160.0
# 3                   2585.0                    1849.0
# 4                   2411.0                    1626.0
# 5                   2127.0                    1506.0
# 6                   2166.0                    1394.0
# 7                   2162.0                    1338.0
# 8                   2560.0                    1516.0
# 9                   3054.0                    1486.0
# 10                  3276.0                    1659.0
# 11                  2941.0                    1569.0
# 12                  2523.0                    1333.0
# 13                  4889.0                    1879.0
#
#     F_Associate'_degree_occupational  F_Associate_degree_academic  F_Bachelor  \
# 1                              314.0                        675.0        1938
# 3                              481.0                        788.0        3561
# 4                              491.0                        741.0        3423
# 5                              417.0                        790.0        3081
# 6                              463.0                        719.0        2651
# 7                              512.0                        711.0        2591
# 8                              454.0                        735.0        2567
# 9                              570.0                        805.0        2514
# 10                             534.0                        826.0        2385
# 11                             467.0                        707.0        1874
# 12                             386.0                        517.0        1419
# 13                             473.0                        607.0        1967
#
#     F_Master  F_Professional  F_Doctoral  Male_Degree  Female_Degree
# 1        149               2           3         1613           2092
# 3       1078             101         121         3945           4861
# 4       1557             171         249         4290           5400
# 5       1656             179         256         4212           5172
# 6       1592             210         228         3878           4681
# 7       1397             179         257         3571           4424
# 8       1380             134         236         3791           4317
# 9       1112             107         158         3257           3891
# 10      1050             109         197         3273           3741
# 11      1011             101         149         3053           3135
# 12       906              81         131         2642           2537
# 13      1054             103         161         3682           3285
#
# [12 rows x 48 columns]

# %% [markdown]
# **The final data frame**

# %%
df.head()
# Out:
#         Characteristics  None  B_1st _4th_grade  B_ 5th _6th_grade  \
# 1  \t\t  18 to 24 years  45.0              23.0               61.0
# 3  \t\t  25 to 29 years  35.0              24.0               92.0
# 4  \t\t  30 to 34 years  34.0              52.0              162.0
# 5  \t\t  35 to 39 years  48.0              99.0              277.0
# 6  \t\t  40 to 44 years  34.0             113.0              308.0
#
#    B _7th _8th_grade  B_9th_grade  B_10th_grade  B_11th_grade2  \
# 1              177.0        236.0         491.0         3249.0
# 3              127.0        187.0         176.0          640.0
# 4              193.0        265.0         231.0          634.0
# 5              280.0        311.0         292.0          571.0
# 6              299.0        315.0         270.0          566.0
#
#    B_High_school_graduate  B_Some_college_no_degree  ...  \
# 1                  9194.0                    9869.0  ...
# 3                  6305.0                    3891.0  ...
# 4                  5627.0                    3438.0  ...
# 5                  5002.0                    3083.0  ...
# 6                  5039.0                    2744.0  ...
#
#    F_High_school_graduate  F_Some_college_no_degree  \
# 1                  4061.0                    5160.0
# 3                  2585.0                    1849.0
# 4                  2411.0                    1626.0
# 5                  2127.0                    1506.0
# 6                  2166.0                    1394.0
#
#    F_Associate'_degree_occupational  F_Associate_degree_academic  F_Bachelor  \
# 1                             314.0                        675.0        1938
# 3                             481.0                        788.0        3561
# 4                             491.0                        741.0        3423
# 5                             417.0                        790.0        3081
# 6                             463.0                        719.0        2651
#
#    F_Master  F_Professional  F_Doctoral  Male_Degree  Female_Degree
# 1       149               2           3         1613           2092
# 3      1078             101         121         3945           4861
# 4      1557             171         249         4290           5400
# 5      1656             179         256         4212           5172
# 6      1592             210         228         3878           4681
#
# [5 rows x 48 columns]

# %%
df
# Out:
#          Characteristics   None  B_1st _4th_grade  B_ 5th _6th_grade  \
# 1   \t\t  18 to 24 years   45.0              23.0               61.0
# 3   \t\t  25 to 29 years   35.0              24.0               92.0
# 4   \t\t  30 to 34 years   34.0              52.0              162.0
# 5   \t\t  35 to 39 years   48.0              99.0              277.0
# 6   \t\t  40 to 44 years   34.0             113.0              308.0
# 7   \t\t  45 to 49 years   71.0             103.0              302.0
# 8   \t\t  50 to 54 years   80.0             125.0              244.0
# 9   \t\t  55 to 59 years   56.0             168.0              280.0
# 10  \t\t  60 to 64 years   96.0             160.0              291.0
# 11  \t\t  65 to 69 years   67.0             121.0              228.0
# 12  \t\t  70 to 74 years   82.0             118.0              189.0
# 13  \t 75 years and over  130.0             259.0              412.0
#
#     B _7th _8th_grade  B_9th_grade  B_10th_grade  B_11th_grade2  \
# 1               177.0        236.0         491.0         3249.0
# 3               127.0        187.0         176.0          640.0
# 4               193.0        265.0         231.0          634.0
# 5               280.0        311.0         292.0          571.0
# 6               299.0        315.0         270.0          566.0
# 7               265.0        236.0         254.0          460.0
# 8               293.0        289.0         223.0          491.0
# 9               269.0        260.0         329.0          601.0
# 10              263.0        242.0         275.0          637.0
# 11              229.0        170.0         229.0          495.0
# 12              250.0        198.0         254.0          375.0
# 13              610.0        355.0         465.0          823.0
#
#     B_High_school_graduate  B_Some_college_no_degree  ...  \
# 1                   9194.0                    9869.0  ...
# 3                   6305.0                    3891.0  ...
# 4                   5627.0                    3438.0  ...
# 5                   5002.0                    3083.0  ...
# 6                   5039.0                    2744.0  ...
# 7                   4910.0                    2618.0  ...
# 8                   5509.0                    2772.0  ...
# 9                   6147.0                    2978.0  ...
# 10                  6581.0                    3197.0  ...
# 11                  5415.0                    3017.0  ...
# 12                  4205.0                    2464.0  ...
# 13                  7807.0                    3254.0  ...
#
#     F_High_school_graduate  F_Some_college_no_degree  \
# 1                   4061.0                    5160.0
# 3                   2585.0                    1849.0
# 4                   2411.0                    1626.0
# 5                   2127.0                    1506.0
# 6                   2166.0                    1394.0
# 7                   2162.0                    1338.0
# 8                   2560.0                    1516.0
# 9                   3054.0                    1486.0
# 10                  3276.0                    1659.0
# 11                  2941.0                    1569.0
# 12                  2523.0                    1333.0
# 13                  4889.0                    1879.0
#
#     F_Associate'_degree_occupational  F_Associate_degree_academic  F_Bachelor  \
# 1                              314.0                        675.0        1938
# 3                              481.0                        788.0        3561
# 4                              491.0                        741.0        3423
# 5                              417.0                        790.0        3081
# 6                              463.0                        719.0        2651
# 7                              512.0                        711.0        2591
# 8                              454.0                        735.0        2567
# 9                              570.0                        805.0        2514
# 10                             534.0                        826.0        2385
# 11                             467.0                        707.0        1874
# 12                             386.0                        517.0        1419
# 13                             473.0                        607.0        1967
#
#     F_Master  F_Professional  F_Doctoral  Male_Degree  Female_Degree
# 1        149               2           3         1613           2092
# 3       1078             101         121         3945           4861
# 4       1557             171         249         4290           5400
# 5       1656             179         256         4212           5172
# 6       1592             210         228         3878           4681
# 7       1397             179         257         3571           4424
# 8       1380             134         236         3791           4317
# 9       1112             107         158         3257           3891
# 10      1050             109         197         3273           3741
# 11      1011             101         149         3053           3135
# 12       906              81         131         2642           2537
# 13      1054             103         161         3682           3285
#
# [12 rows x 48 columns]
